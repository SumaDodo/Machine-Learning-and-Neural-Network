# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("amazon.csv" ,encoding = "ISO-8859-1")
df.head()
# Out:
#    year state    month  number        date
# 0  1998  Acre  Janeiro     0.0  1998-01-01
# 1  1999  Acre  Janeiro     0.0  1999-01-01
# 2  2000  Acre  Janeiro     0.0  2000-01-01
# 3  2001  Acre  Janeiro     0.0  2001-01-01
# 4  2002  Acre  Janeiro     0.0  2002-01-01

# %%
yearly_number = pd.pivot_table(df, values="number", index =["year"], aggfunc=np.sum)

# %%
yearly_number
# Out:
#          number
# year
# 1998  20013.971
# 1999  26882.821
# 2000  27351.251
# 2001  29071.612
# 2002  37390.600
# 2003  42760.674
# 2004  38453.163
# 2005  35004.965
# 2006  33832.161
# 2007  33037.413
# 2008  29378.964
# 2009  39117.178
# 2010  37037.449
# 2011  34633.545
# 2012  40084.860
# 2013  35146.118
# 2014  39621.183
# 2015  41208.292
# 2016  42212.229
# 2017  36685.624

# %%
monthly_number = pd.pivot_table(df, values = "number", index=["month"], aggfunc=np.sum)

# %%
monthly_number
# Out:
#               number
# month
# Abril      28188.770
# Agosto     88050.435
# Dezembro   57535.480
# Fevereiro  30848.050
# Janeiro    47747.844
# Julho      92326.113
# Junho      56010.675
# Maio       34731.363
# Março      30717.405
# Novembro   85508.054
# Outubro    88681.579
# Setembro   58578.305

# %%
state_number = pd.pivot_table(df, values ="number", index=["state"], aggfunc =np.sum)

# %%
state_number
# Out:
#                      number
# state
# Acre              18464.030
# Alagoas            4644.000
# Amapa             21831.576
# Amazonas          30650.129
# Bahia             44746.226
# Ceara             30428.063
# Distrito Federal   3561.000
# Espirito Santo     6546.000
# Goias             37695.520
# Maranhao          25129.131
# Mato Grosso       96246.028
# Minas Gerais      37475.258
# Paraiba           52435.918
# Pará              24512.144
# Pernambuco        24498.000
# Piau              37803.747
# Rio               45160.865
# Rondonia          20285.429
# Roraima           24385.074
# Santa Catarina    24359.852
# Sao Paulo         51121.198
# Sergipe            3237.000
# Tocantins         33707.885

# %%
#plt.figure(figsize=(15,6))
plt.grid(state_number)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-49e0753d21f1> in <module>()
#       1 #plt.figure(figsize=(15,6))
# ----> 2 plt.grid(state_number)
#       3 plt.xticks(rotation='vertical')
#       4 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in grid(b, which, axis, **kwargs)
#    3810 @docstring.copy_dedent(Axes.grid)
#    3811 def grid(b=None, which='major', axis='both', **kwargs):
# -> 3812     ret = gca().grid(b=b, which=which, axis=axis, **kwargs)
#    3813     return ret
#    3814
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in grid(self, b, which, axis, **kwargs)
#    2705             b = True
#    2706         elif b is not None:
# -> 2707             b = _string_to_bool(b)
#    2708
#    2709         if axis == 'x' or axis == 'both':
#
# ...

# %%
plt.plot(monthly_number)
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.plot(yearly_number)
plt.xticks(rotation='vertical')
plt.show()
